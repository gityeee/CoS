# %% [markdown]
# <a href="https://colab.research.google.com/github/forminju/CoS/blob/main/%5B0112%5D_1037%2B2798.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## 1037 약수
# 양수 A가 N의 진짜 약수가 되려면, N이 A의 배수이고, A가 1과 N이 아니어야 한다. 어떤 수 N의 진짜 약수가 모두 주어질 때, N을 구하는 프로그램을 작성하시오.

# %%
#1037. 약수

n = int(input())
a = list(map(int, input().split()))

print(max(a)*min(a))
# Out:
# 2
# 4 2
# 8

# %% [markdown]
# ##2798 블랙잭
# 카지노에서 제일 인기 있는 게임 블랙잭의 규칙은 상당히 쉽다. 카드의 합이 21을 넘지 않는 한도 내에서, 카드의 합을 최대한 크게 만드는 게임이다. 블랙잭은 카지노마다 다양한 규정이 있다.
#
# 한국 최고의 블랙잭 고수 김정인은 새로운 블랙잭 규칙을 만들어 상근, 창영이와 게임하려고 한다.
#
# 김정인 버전의 블랙잭에서 각 카드에는 양의 정수가 쓰여 있다. 그 다음, 딜러는 N장의 카드를 모두 숫자가 보이도록 바닥에 놓는다. 그런 후에 딜러는 숫자 M을 크게 외친다.
#
# 이제 플레이어는 제한된 시간 안에 N장의 카드 중에서 3장의 카드를 골라야 한다. 블랙잭 변형 게임이기 때문에, 플레이어가 고른 카드의 합은 M을 넘지 않으면서 M과 최대한 가깝게 만들어야 한다.
#
# N장의 카드에 써져 있는 숫자가 주어졌을 때, M을 넘지 않으면서 M에 최대한 가까운 카드 3장의 합을 구해 출력하시오.

# %%
# N장의 카드 중 3장의 카드를 골라 M을 넘지 않는 M과 가장 가까운 수 출력

# %% [markdown]
# ![KakaoTalk_20230112_085236775.jpg](data:image/jpeg;base64,...)

# %%
m, n = map(int, input().split())  #5장의 카드 중 3장을 뽑아 21과 가장 가까운 수를 만들어야 한다!

li = list(map(int, input().split()))
li.sort()

for i in range(m, 0, -1):
  for j in range(m-1, i, -1):
    for k in range(m-2, j, -1):
      if li[i]+li[j]+li[k] >n :
        continue
      else:
        result = li[i]+li[j]+li[k]


print(result)
# FALSE
# Out:
# 10 500
# 93 181 245 214 315 36 185 138 216 295
# 412

# %% [markdown]
# ![KakaoTalk_20230112_085804674.jpg](data:image/jpeg;base64,...)

# %%
m, n = map(int, input().split())  #5장의 카드 중 3장을 뽑아 21과 가장 가까운 수를 만들어야 한다!

li = list(map(int, input().split()))
li.sort()

for i in range(m):
  for j in range(i+1, m):
    for k in range(j+1, m):
      if li[i]+li[j]+li[k] >n :
        continue
      else:
        result = max(result, li[i]+li[j]+li[k])


print(result)
# Out:
# 10 500
# 93 181 245 214 315 36 185 138 216 295
# 497
